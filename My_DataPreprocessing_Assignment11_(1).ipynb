# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashwini-Padige/Machine-Learning-Algorithms/blob/main/My_DataPreprocessing_Assignment11_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Data.csv

# %% [markdown]
# **Step 1: Importing the libraries**

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %% [markdown]
# **Step 2: Importing dataset**

# %%
ds = pd.read_csv("Data.csv")
ds.head()
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes

# %% [markdown]
# **Step 3: Handling the missing data**

# %%
ds.isnull().sum()
# Out:
# Country      0
# Age          1
# Salary       1
# Purchased    0
# dtype: int64

# %% [markdown]
# replacing Nan value in salary with mean

# %%
ds["Salary"] = ds["Salary"].fillna(ds["Salary"].mean())
ds
# Out:
#    Country   Age        Salary Purchased
# 0   France  44.0  72000.000000        No
# 1    Spain  27.0  48000.000000       Yes
# 2  Germany  30.0  54000.000000        No
# 3    Spain  38.0  61000.000000        No
# 4  Germany  40.0  63777.777778       Yes
# 5   France  35.0  58000.000000       Yes
# 6    Spain   NaN  52000.000000        No
# 7   France  48.0  79000.000000       Yes
# 8  Germany  50.0  83000.000000        No
# 9   France  37.0  67000.000000       Yes

# %% [markdown]
# for missing Age i m seeing relation of age with salary with purchased

# %%
import matplotlib.pyplot as plt
x = np.array(ds["Age"])
y = np.array(ds["Salary"])

plt.title("salary vs age")
plt.bar(x,y)
plt.show()

# %%
ds["Age"].fillna(38, inplace = True)
ds
# Out:
#    Country   Age        Salary Purchased
# 0   France  44.0  72000.000000        No
# 1    Spain  27.0  48000.000000       Yes
# 2  Germany  30.0  54000.000000        No
# 3    Spain  38.0  61000.000000        No
# 4  Germany  40.0  63777.777778       Yes
# 5   France  35.0  58000.000000       Yes
# 6    Spain  38.0  52000.000000        No
# 7   France  48.0  79000.000000       Yes
# 8  Germany  50.0  83000.000000        No
# 9   France  37.0  67000.000000       Yes

# %% [markdown]
# **Step 4: Encoding categorical data**

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
ds['Purchased'] = le.fit_transform(ds['Purchased'])
ds
# Out:
#    Country   Age        Salary  Purchased
# 0   France  44.0  72000.000000          0
# 1    Spain  27.0  48000.000000          1
# 2  Germany  30.0  54000.000000          0
# 3    Spain  38.0  61000.000000          0
# 4  Germany  40.0  63777.777778          1
# 5   France  35.0  58000.000000          1
# 6    Spain  38.0  52000.000000          0
# 7   France  48.0  79000.000000          1
# 8  Germany  50.0  83000.000000          0
# 9   France  37.0  67000.000000          1

# %% [markdown]
# **Step 5: Creating a dummy variable**

# %%
pd.get_dummies(ds)
# Out:
#     Age        Salary  Purchased  Country_France  Country_Germany  \
# 0  44.0  72000.000000          0               1                0
# 1  27.0  48000.000000          1               0                0
# 2  30.0  54000.000000          0               0                1
# 3  38.0  61000.000000          0               0                0
# 4  40.0  63777.777778          1               0                1
# 5  35.0  58000.000000          1               1                0
# 6  38.0  52000.000000          0               0                0
# 7  48.0  79000.000000          1               1                0
# 8  50.0  83000.000000          0               0                1
# 9  37.0  67000.000000          1               1                0
#
#    Country_Spain
# 0              0
# 1              1
# 2              0
# 3              1
# 4              0
# 5              0
# 6              1
# 7              0
# 8              0
# 9              0

# %% [markdown]
# **Step 6: Splitting the datasets into training sets and Test sets**

# %%
x=ds[['Country', 'Age', 'Salary']].values
y=ds[ 'Purchased'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %% [markdown]
# **Step 7: Feature Scaling**

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
